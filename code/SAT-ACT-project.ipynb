# %% [markdown]
# # Project 1: SAT & ACT Analysis

# %% [markdown]
# ## Problem Statement

# %% [markdown]
# How can we increase SAT participation rates in states with high score like North Dakota?  Should the tests be mandatory if 100% partipation states have lower averages?  If yes, should they be nationally standardized?  Are they even helpful anymore since many colleges are dropping their requirement?

# %% [markdown]
# ## Executive Summary
#
# The 2017 and 2018 data shows a correlation between high particpation rates and lower scores as well as low participation rates and higher scores for both the SAT and ACT tests. The tests themselves are standardized, however, who has to take them is not. There are many outside factors that affect the average scores as well as the popularity of each test per state.
#
#
# ### Contents:
# - [2017 Data Import & Cleaning](#Data-Import-and-Cleaning)
# - [2018 Data Import and Cleaning](#2018-Data-Import-and-Cleaning)
# - [Exploratory Data Analysis](#Exploratory-Data-Analysis)
# - [Data Visualization](#Visualize-the-data)
# - [Descriptive and Inferential Statistics](#Descriptive-and-Inferential-Statistics)
# - [Outside Research](#Outside-Research)
# - [Conclusions and Recommendations](#Conclusions-and-Recommendations)

# %% [markdown]
# **If you combine your problem statement, executive summary, data dictionary, and conclusions/recommendations, you have an amazing README.md file that quickly aligns your audience to the contents of your project.** Don't forget to cite your data sources!

# %% [markdown]
# *All libraries used should be added here*

# %%
#Imports:
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## 2017 Data Import and Cleaning

# %% [markdown]
# #### 1. Read In SAT & ACT  Data
#
# Read in the `sat_2017.csv` and `act_2017.csv` files and assign them to appropriately named pandas dataframes.

# %%
#Code:
sat17 = pd.read_csv('../data/sat_2017.csv')
act17 = pd.read_csv('../data/act_2017.csv')

# %% [markdown]
# #### 2. Display Data
#
# Print the first 10 rows of each dataframe to your jupyter notebook

# %%
#Code:
sat17.head(10)
# Out:
#                   State Participation  Evidence-Based Reading and Writing  \
# 0               Alabama            5%                                 593
# 1                Alaska           38%                                 547
# 2               Arizona           30%                                 563
# 3              Arkansas            3%                                 614
# 4            California           53%                                 531
# 5              Colorado           11%                                 606
# 6           Connecticut          100%                                 530
# 7              Delaware          100%                                 503
# 8  District of Columbia          100%                                 482
# 9               Florida           83%                                 520
#
#    Math  Total
# 0   572   1165
# 1   533   1080
# 2   553   1116
# 3   594   1208
# 4   524   1055
# 5   595   1201
# 6   512   1041
# 7   492    996
# ...

# %%
act17.head(10)
# Out:
#                   State Participation  English  Math  Reading  Science  \
# 0              National           60%     20.3  20.7     21.4     21.0
# 1               Alabama          100%     18.9  18.4     19.7     19.4
# 2                Alaska           65%     18.7  19.8     20.4     19.9
# 3               Arizona           62%     18.6  19.8     20.1     19.8
# 4              Arkansas          100%     18.9  19.0     19.7     19.5
# 5            California           31%     22.5  22.7     23.1     22.2
# 6              Colorado          100%     20.1  20.3     21.2     20.9
# 7           Connecticut           31%     25.5  24.6     25.6     24.6
# 8              Delaware           18%     24.1  23.4     24.8     23.6
# 9  District of Columbia           32%     24.4  23.5     24.9     23.5
#
#   Composite
# 0      21.0
# 1      19.2
# 2      19.8
# 3      19.7
# 4      19.4
# 5      22.8
# 6      20.8
# 7      25.2
# 8      24.1
# 9      24.2

# %% [markdown]
# #### 3. Verbally Describe Data
#
# Take your time looking through the data and thoroughly describe the data in the markdown cell below.

# %%
sat17.describe()
# Out:
#        Evidence-Based Reading and Writing        Math        Total
# count                           51.000000   51.000000    51.000000
# mean                           569.117647  547.627451  1126.098039
# std                             45.666901   84.909119    92.494812
# min                            482.000000   52.000000   950.000000
# 25%                            533.500000  522.000000  1055.500000
# 50%                            559.000000  548.000000  1107.000000
# 75%                            613.000000  599.000000  1212.000000
# max                            644.000000  651.000000  1295.000000

# %% [markdown]
# Answer: Both SAT and ACT datasets show us the average scores by state as well as the national averages.  ACT tests a students knowledge of science and English, SAT tests cover writing and  both include math and reading scores. We can also see that DC got the lowest SAT scores and Minnesota got the highest.  Nevada has the lowest ACT composite score while New Hampshire has the highest. We can also find the mean of all scores, and the highest and lowest scores.
#
# We can also see that Participation and Composite columns start out at object types even though they appear to be integers and floats.

# %%
act17.describe()
# Out:
#          English       Math    Reading    Science
# count  52.000000  52.000000  52.000000  52.000000
# mean   20.919231  21.173077  22.001923  21.040385
# std     2.332132   1.963602   2.048672   3.151113
# min    16.300000  18.000000  18.100000   2.300000
# 25%    19.000000  19.400000  20.475000  19.900000
# 50%    20.550000  20.900000  21.700000  21.150000
# 75%    23.300000  23.100000  24.125000  22.525000
# max    25.500000  25.300000  26.000000  24.900000

# %%
sat17.sort_values('Total').head()
# Out:
#                    State Participation  Evidence-Based Reading and Writing  \
# 8   District of Columbia          100%                                 482
# 7               Delaware          100%                                 503
# 12                 Idaho           93%                                 513
# 22              Michigan          100%                                 509
# 19                 Maine           95%                                 513
#
#     Math  Total
# 8    468    950
# 7    492    996
# 12   493   1005
# 22   495   1005
# 19   499   1012

# %%
act17.sort_values('Composite').head()
# Out:
#              State Participation  English  Math  Reading  Science Composite
# 29          Nevada          100%     16.3  18.0     18.1     18.2      17.8
# 25     Mississippi          100%     18.2  18.1     18.8     18.8      18.6
# 41  South Carolina          100%     17.5  18.6     19.1     18.9      18.7
# 12          Hawaii           90%     17.8  19.2     19.2     19.3      19.0
# 34  North Carolina          100%     17.8  19.3     19.6     19.3      19.1

# %%
print(sat17.shape)
print(act17.shape)
# Out:
# (51, 5)
# (52, 7)

# %%
sat17.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 5 columns):
# State                                 51 non-null object
# Participation                         51 non-null object
# Evidence-Based Reading and Writing    51 non-null int64
# Math                                  51 non-null int64
# Total                                 51 non-null int64
# dtypes: int64(3), object(2)
# memory usage: 2.1+ KB

# %%
act17.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 7 columns):
# State            52 non-null object
# Participation    52 non-null object
# English          52 non-null float64
# Math             52 non-null float64
# Reading          52 non-null float64
# Science          52 non-null float64
# Composite        52 non-null object
# dtypes: float64(4), object(3)
# memory usage: 2.9+ KB

# %% [markdown]
# #### 4a. Does the data look complete?

# %%
sat17.isnull().sum()
# Out:
# State                                 0
# Participation                         0
# Evidence-Based Reading and Writing    0
# Math                                  0
# Total                                 0
# dtype: int64

# %%
act17.isnull().sum()
# Out:
# State            0
# Participation    0
# English          0
# Math             0
# Reading          0
# Science          0
# Composite        0
# dtype: int64

# %% [markdown]
# Answer:  The data appears complete at first glance because there are no null value cells.

# %% [markdown]
# #### 4b. Are there any obvious issues with the observations?
#
# **What is the minimum *possible* value for each test/subtest? What is the maximum *possible* value?**
#
# Consider comparing any questionable values to the sources of your data:
# - [SAT](https://blog.collegevine.com/here-are-the-average-sat-scores-by-state/)
# - [ACT](https://blog.prepscholar.com/act-scores-by-state-averages-highs-and-lows)

# %% [markdown]
# Answer: Yes, there appears to be an issue with the minimum value for sat17 Math.  It has a value of 52 right now, but the actual min possible score is 200.  The min value for act17 Science also looks weird at 2.3. It is technically possible because ACTs are given a score from 1 to 36, but should probably double check.

# %% [markdown]
# #### 4c. Fix any errors you identified
#
# **The data is available** so there's no need to guess or calculate anything. If you didn't find any errors, continue to the next step.

# %%
#code

sat17.sort_values(['Math', 'State']).head()
# Out:
#                    State Participation  Evidence-Based Reading and Writing  \
# 20              Maryland           69%                                 536
# 8   District of Columbia          100%                                 482
# 7               Delaware          100%                                 503
# 12                 Idaho           93%                                 513
# 22              Michigan          100%                                 509
#
#     Math  Total
# 20    52   1060
# 8    468    950
# 7    492    996
# 12   493   1005
# 22   495   1005

# %% [markdown]
# Sorting the values by Math and State columns we can see that Maryland has the error score of 52.  After cross checking our given resource https://blog.collegevine.com/here-are-the-average-sat-scores-by-state/ , I can see it should actually be 524.

# %%
sat17['Math'] = (sat17['Math'].replace(52, 524))

# %%
sat17.loc[sat17['State'] == 'Maryland']
# Out:
#        State Participation  Evidence-Based Reading and Writing  Math  Total
# 20  Maryland           69%                                 536   524   1060

# %%
act17.sort_values(['Science', 'State']).head()
# Out:
#              State Participation  English  Math  Reading  Science Composite
# 21        Maryland           28%     23.3  23.1     24.2      2.3      23.6
# 29          Nevada          100%     16.3  18.0     18.1     18.2      17.8
# 25     Mississippi          100%     18.2  18.1     18.8     18.8      18.6
# 41  South Carolina          100%     17.5  18.6     19.1     18.9      18.7
# 12          Hawaii           90%     17.8  19.2     19.2     19.3      19.0

# %% [markdown]
# I did the same for act17 with Science and State and Maryland is the culprit again!  According to https://blog.prepscholar.com/act-scores-by-state-averages-highs-and-lows, the score there should really be 23.2.

# %%
act17['Science'] = (act17['Science'].replace(2.3, 23.2))

# %%
act17.loc[act17['State'] == 'Maryland']
# Out:
#        State Participation  English  Math  Reading  Science Composite
# 21  Maryland           28%     23.3  23.1     24.2     23.2      23.6

# %% [markdown]
# #### 5. What are your data types?
# Display the data types of each feature.

# %%
#code
sat17.dtypes
# Out:
# State                                 object
# Participation                         object
# Evidence-Based Reading and Writing     int64
# Math                                   int64
# Total                                  int64
# dtype: object

# %%
act17.dtypes
# Out:
# State             object
# Participation     object
# English          float64
# Math             float64
# Reading          float64
# Science          float64
# Composite         object
# dtype: object

# %% [markdown]
# What did you learn?
# - Do any of them seem odd?
# - Which ones are not as they should be?

# %% [markdown]
# Answer: **Yes, Participation and Composite are currently object/strings but should be integers**

# %% [markdown]
# #### 6. Fix Incorrect Data Types
# Based on what you discovered above, use appropriate methods to re-type incorrectly typed data.
# - Define a function that will allow you to convert participation rates to an appropriate numeric type. Use `map` or `apply` to change these columns in each dataframe.

# %%
act17["Composite"].sort_values()
# Out:
# 29     17.8
# 25     18.6
# 41     18.7
# 12     19.0
# 34     19.1
# 1      19.2
# 4      19.4
# 37     19.4
# 19     19.5
# 3      19.7
# 32     19.7
# 2      19.8
# 43     19.8
# 10     19.8
# 18     20.0
# 51    20.2x
# 35     20.3
# 27     20.3
# 45     20.3
# 49     20.4
# 26     20.4
# 50     20.5
# 44     20.7
# 6      20.8
# 0      21.0
# 14     21.4
# 28     21.4
# 11     21.4
# 24     21.5
# 17     21.7
# 42     21.8
# 38     21.8
# 48     21.9
# 16     21.9
# 36     22.0
# 13     22.3
# 15     22.6
# 5      22.8
# 46     23.6
# 21     23.6
# 39     23.7
# 47     23.8
# 31     23.9
# 40     24.0
# 8      24.1
# 23     24.1
# 9      24.2
# 33     24.2
# 20     24.3
# 7      25.2
# 22     25.4
# 30     25.5
# Name: Composite, dtype: object

# %%
#code
act17[act17["Composite"].str.contains("x")]
# Out:
#       State Participation  English  Math  Reading  Science Composite
# 51  Wyoming          100%     19.4  19.8     20.8     20.6     20.2x

# %%
act17['Composite'] = (act17['Composite'].replace('20.2x', '20.2'))

# %%
act17['Composite'] = act17[["Composite"]].astype(float)

# %%
act17['Composite'].dtypes
# Out:
# dtype('float64')

# %%
act17['Participation'].value_counts(ascending = True)
# Out:
# 45%      1
# 65%      1
# 62%      1
# 40%      1
# 90%      1
# 80%      1
# 98%      1
# 38%      1
# 23%      1
#  60%     1
# 75%      1
# 66%      1
# 35%      1
# 21%      1
# 28%      1
# 93%      1
# 69%      1
# 8%       1
# 55%      1
# 32%      1
# 67%      1
# 34%      1
# 84%      1
# 73%      2
# 18%      2
# 31%      3
# 29%      5
# 100%    17
# Name: Participation, dtype: int64

# %%
def percent_to_float(participation_cell):
    participation_cell = participation_cell.replace("%", "")
    
    return(float(participation_cell))

# %%
act17['Participation'] = act17['Participation'].map(percent_to_float)

# %% [markdown]
# - Fix any individual values preventing other columns from being the appropriate type.

# %%
#code
sat17['Participation'] = sat17['Participation'].map(percent_to_float)

# %% [markdown]
# - Finish your data modifications by making sure the columns are now typed appropriately.

# %%
#code
print(act17['Composite'].dtypes)
print (act17['Participation'].dtypes)
print (sat17['Participation'].dtypes)
# Out:
# float64
# float64
# float64

# %% [markdown]
# - Display the data types again to confirm they are correct.

# %%
sat17.dtypes
# Out:
# State                                  object
# Participation                         float64
# Evidence-Based Reading and Writing      int64
# Math                                    int64
# Total                                   int64
# dtype: object

# %%
#Code:
act17.dtypes
# Out:
# State             object
# Participation    float64
# English          float64
# Math             float64
# Reading          float64
# Science          float64
# Composite        float64
# dtype: object

# %% [markdown]
# #### 7. Rename Columns
# Change the names of the columns to more expressive names so that you can tell the difference the SAT columns and the ACT columns. Your solution should map all column names being changed at once (no repeated singular name-changes). **We will be combining these data with some of the data from 2018, and so you should name columns in an appropriate way**.
#
# **Guidelines**:
# - Column names should be all lowercase (you will thank yourself when you start pushing data to SQL later in the course)
# - Column names should not contain spaces (underscores will suffice--this allows for using the `df.column_name` method to access columns in addition to `df['column_name']`.
# - Column names should be unique and informative (the only feature that we actually share between dataframes is the state).

# %%
sat17.columns
# Out:
# Index(['State', 'Participation', 'Evidence-Based Reading and Writing', 'Math',
#        'Total'],
#       dtype='object')

# %%
#code

sat17_mapper = {
    'State': 'state',
    'Participation': 'sat_participation_2017',
    'Evidence-Based Reading and Writing': 'sat_rw_2017',
    'Math': 'sat_math_2017',
    'Total': 'sat_total_2017'
}

# %%
sat17.rename(columns =sat17_mapper, inplace = True)

# %%
sat17.head()
# Out:
#         state  sat_participation_2017  sat_rw_2017  sat_math_2017  \
# 0     Alabama                     5.0          593            572
# 1      Alaska                    38.0          547            533
# 2     Arizona                    30.0          563            553
# 3    Arkansas                     3.0          614            594
# 4  California                    53.0          531            524
#
#    sat_total_2017
# 0            1165
# 1            1080
# 2            1116
# 3            1208
# 4            1055

# %%
act17.columns
# Out:
# Index(['State', 'Participation', 'English', 'Math', 'Reading', 'Science',
#        'Composite'],
#       dtype='object')

# %%
act17_mapper = {
    'State': 'state',
    'Participation': 'act_participation_2017',
    'English': 'act_english_2017',
    'Math': 'act_math_2017',
    'Reading': 'act_reading_2017',
    'Science': 'act_science_2017',
    'Composite': 'act_composite_2017'
}

# %%
act17.rename(columns = act17_mapper, inplace = True)

# %%
act17.head()
# Out:
#       state  act_participation_2017  act_english_2017  act_math_2017  \
# 0  National                    60.0              20.3           20.7
# 1   Alabama                   100.0              18.9           18.4
# 2    Alaska                    65.0              18.7           19.8
# 3   Arizona                    62.0              18.6           19.8
# 4  Arkansas                   100.0              18.9           19.0
#
#    act_reading_2017  act_science_2017  act_composite_2017
# 0              21.4              21.0                21.0
# 1              19.7              19.4                19.2
# 2              20.4              19.9                19.8
# 3              20.1              19.8                19.7
# 4              19.7              19.5                19.4

# %% [markdown]
# #### 8. Create a data dictionary
#
# Now that we've fixed our data, and given it appropriate names, let's create a [data dictionary](http://library.ucmerced.edu/node/10249).
#
# A data dictionary provides a quick overview of features/variables/columns, alongside data types and descriptions. The more descriptive you can be, the more useful this document is.
#
#
# [Here's a quick link to a short guide for formatting markdown in Jupyter notebooks](https://jupyter-notebook.readthedocs.io/en/stable/examples/Notebook/Working%20With%20Markdown%20Cells.html).

# %% [markdown]
# |Feature|Type|Dataset|Description|
# |---|---|---|---|
# |state|object|SAT|This is the state where students took the SATs.|
# |sat_participation_2017|float|SAT|The percent of students that took the test in their state.|
# |sat_rw_2017|int|SAT|The average score for the Evidence-Based Reading and Writing portion of the test for each state.|
# |sat_math_2017|int|SAT|The average score for the Math portion of the test for each state.|
# |sat_total_2017|int|SAT|The average of the Reading & Writing and Math scores added together for each state.|
# |state|object|ACT|This is the state where students took the ACTs.|
# |act_participation_2017|float|ACT|The percent of students that took the test in their state.|
# |act_english_2017|float|ACT|The average score for the English portion of the test in each state.|
# |act_math_2017|float|ACT|The average score for the Math portion of the test in each state.|
# |act_reading_2017|float|ACT|The average score for the Reading portion of the test in each state.|
# |act_science_2017|float|ACT|The average score for the Science portion of the test in each state.
# |act_composite_2017|float|ACT|The average score for the total of all 4 portions of the test in each state.|
# |sat_participation_2018|float|SAT|The percent of students that took the test in their state in 2018.|
# |sat_rw_2018|int|SAT|The average score for the Evidence-Based Reading and Writing portion of the test for each state in 2018.|
# |sat_math_2018|int|SAT|The average score for the Math portion of the test for each state in 2018.|
# |sat_total_2018|int|SAT|The average of the Reading & Writing and Math scores added together for each state in 2018.|
# |act_participation_2018|float|ACT|The percent of students that took the test in their state in 2018.|
# |act_composite_2018|float|ACT|The average score for the total of all 4 portions of the test in each state in 2018.|

# %%
final_df.head()
# Out:
#         state  sat_participation_2017  sat_rw_2017  sat_math_2017  \
# 0     Alabama                     5.0          593            572
# 1      Alaska                    38.0          547            533
# 2     Arizona                    30.0          563            553
# 3    Arkansas                     3.0          614            594
# 4  California                    53.0          531            524
#
#    sat_total_2017  act_participation_2017  act_english_2017  act_math_2017  \
# 0            1165                   100.0              18.9           18.4
# 1            1080                    65.0              18.7           19.8
# 2            1116                    62.0              18.6           19.8
# 3            1208                   100.0              18.9           19.0
# 4            1055                    31.0              22.5           22.7
#
#    act_reading_2017  act_science_2017  act_composite_2017  \
# ...

# %% [markdown]
# #### 9. Drop unnecessary rows
#
# One of our dataframes contains an extra row. Identify and remove this from the dataframe.

# %%
#code
act17.drop(labels=0, inplace = True)

# %%
act17
# Out:
#                    state  act_participation_2017  act_english_2017  \
# 1                Alabama                   100.0              18.9
# 2                 Alaska                    65.0              18.7
# 3                Arizona                    62.0              18.6
# 4               Arkansas                   100.0              18.9
# 5             California                    31.0              22.5
# 6               Colorado                   100.0              20.1
# 7            Connecticut                    31.0              25.5
# 8               Delaware                    18.0              24.1
# 9   District of Columbia                    32.0              24.4
# 10               Florida                    73.0              19.0
# 11               Georgia                    55.0              21.0
# 12                Hawaii                    90.0              17.8
# 13                 Idaho                    38.0              21.9
# ...

# %%
sat17
# Out:
#                    state  sat_participation_2017  sat_rw_2017  sat_math_2017  \
# 0                Alabama                     5.0          593            572
# 1                 Alaska                    38.0          547            533
# 2                Arizona                    30.0          563            553
# 3               Arkansas                     3.0          614            594
# 4             California                    53.0          531            524
# 5               Colorado                    11.0          606            595
# 6            Connecticut                   100.0          530            512
# 7               Delaware                   100.0          503            492
# 8   District of Columbia                   100.0          482            468
# 9                Florida                    83.0          520            497
# 10               Georgia                    61.0          535            515
# ...

# %% [markdown]
# #### 10. Merge Dataframes
#
# Join the 2017 ACT and SAT dataframes using the state in each dataframe as the key. Assign this to a new variable.

# %%
#Code:

combined_2017 = pd.merge(sat17, act17, how='outer', on ='state')

# %%
combined_2017.head()
# Out:
#         state  sat_participation_2017  sat_rw_2017  sat_math_2017  \
# 0     Alabama                     5.0          593            572
# 1      Alaska                    38.0          547            533
# 2     Arizona                    30.0          563            553
# 3    Arkansas                     3.0          614            594
# 4  California                    53.0          531            524
#
#    sat_total_2017  act_participation_2017  act_english_2017  act_math_2017  \
# 0            1165                   100.0              18.9           18.4
# 1            1080                    65.0              18.7           19.8
# 2            1116                    62.0              18.6           19.8
# 3            1208                   100.0              18.9           19.0
# 4            1055                    31.0              22.5           22.7
#
#    act_reading_2017  act_science_2017  act_composite_2017
# 0              19.7              19.4                19.2
# ...

# %% [markdown]
# #### 11. Save your cleaned, merged dataframe
#
# Use a relative path to save out your data as `combined_2017.csv`.

# %%
#code

combined_2017.to_csv(path_or_buf='../data/combined_2017.csv')

# %% [markdown]
# ## 2018 Data Import and Cleaning

# %% [markdown]
# Links to the 2018 ACT and SAT data are provided in the README. These data live in PDFs, and so you'll get to enjoy practicing some *manual* data collection. Save these data as a CSV in your `data` directory, and import, explore, and clean these data in the same way you did above. **Make sure you comment on your steps so it is clear *why* you are doing each process**.

# %%
sat18 = pd.read_csv('../data/SAT_2018.csv')
sat18.head(10)
# Out:
#                   State Participation  Evidence-Based Reading and Writing  \
# 0               Alabama            6%                                 595
# 1                Alaska           43%                                 562
# 2               Arizona           29%                                 577
# 3              Arkansas            5%                                 592
# 4            California           60%                                 540
# 5              Colorado          100%                                 519
# 6           Connecticut          100%                                 535
# 7              Delaware          100%                                 505
# 8  District of Columbia           92%                                 497
# 9               Florida           56%                                 550
#
#    Math  Total
# 0   571   1166
# 1   544   1106
# 2   572   1149
# 3   576   1169
# 4   536   1076
# 5   506   1025
# 6   519   1053
# 7   492    998
# ...

# %%
act18 = pd.read_csv('../data/ACT_2018.csv') 
act18.head(10)
# Out:
#                   State Participation  Composite
# 0               Alabama          100%       19.1
# 1                Alaska           33%       20.8
# 2               Arizona           66%       19.2
# 3              Arkansas          100%       19.4
# 4            California           27%       22.7
# 5              Colorado           30%       23.9
# 6           Connecticut           26%       25.6
# 7              Delaware           17%       23.8
# 8  District of columbia           32%       23.6
# 9               Florida           66%       19.9

# %% [markdown]
# Checking here to see if data looks complete.  It does because there are not any Null or empty cells.

# %%
act18.isnull().sum()
# Out:
# State            0
# Participation    0
# Composite        0
# dtype: int64

# %%
sat18.isnull().sum()
# Out:
# State                                 0
# Participation                         0
# Evidence-Based Reading and Writing    0
# Math                                  0
# Total                                 0
# dtype: int64

# %% [markdown]
# Checking here if there appears to be any errors in the data.  It looks pretty clean except for that ACT has one more row that SAT.

# %%
sat18.describe()
# Out:
#        Evidence-Based Reading and Writing        Math        Total
# count                           51.000000   51.000000    51.000000
# mean                           563.686275  556.235294  1120.019608
# std                             47.502627   47.772623    94.155083
# min                            480.000000  480.000000   977.000000
# 25%                            534.500000  522.500000  1057.500000
# 50%                            552.000000  544.000000  1098.000000
# 75%                            610.500000  593.500000  1204.000000
# max                            643.000000  655.000000  1298.000000

# %%
sat18.shape
# Out:
# (51, 5)

# %%
act18.describe()
# Out:
#        Composite
# count  52.000000
# mean   21.544231
# std     2.119417
# min    17.700000
# 25%    19.975000
# 50%    21.300000
# 75%    23.725000
# max    25.600000

# %%
act18.shape
# Out:
# (52, 3)

# %% [markdown]
# There are less columns for the ACT 2018 data than 2017.  We are missing all the state averages  by subject.

# %%
sat18.columns
# Out:
# Index(['State', 'Participation', 'Evidence-Based Reading and Writing', 'Math',
#        'Total'],
#       dtype='object')

# %%
sat18_mapper = {'State': 'state',
                'Participation': 'sat_participation_2018',
                'Evidence-Based Reading and Writing': 'sat_rw_2018',
                'Math': 'sat_math_2018',
                'Total': 'sat_total_2018'    
}

# %%
sat18.rename(columns =sat18_mapper, inplace = True)

# %%
sat18.head()
# Out:
#         state sat_participation_2018  sat_rw_2018  sat_math_2018  \
# 0     Alabama                     6%          595            571
# 1      Alaska                    43%          562            544
# 2     Arizona                    29%          577            572
# 3    Arkansas                     5%          592            576
# 4  California                    60%          540            536
#
#    sat_total_2018
# 0            1166
# 1            1106
# 2            1149
# 3            1169
# 4            1076

# %%
act18.columns
# Out:
# Index(['State', 'Participation', 'Composite'], dtype='object')

# %%
act18_mapper = {
    'State': 'state',
    'Participation': 'act_participation_2018',
    'Composite': 'act_composite_2018'
    
}

# %%
act18.rename(columns=act18_mapper, inplace=True)

# %%
act18.head()
# Out:
#         state act_participation_2018  act_composite_2018
# 0     Alabama                   100%                19.1
# 1      Alaska                    33%                20.8
# 2     Arizona                    66%                19.2
# 3    Arkansas                   100%                19.4
# 4  California                    27%                22.7

# %%
sat18.dtypes
# Out:
# state                     object
# sat_participation_2018    object
# sat_rw_2018                int64
# sat_math_2018              int64
# sat_total_2018             int64
# dtype: object

# %%
act18.dtypes
# Out:
# state                      object
# act_participation_2018     object
# act_composite_2018        float64
# dtype: object

# %% [markdown]
# After checking the column types, I can see that the Participation columns for both act18 and sat18 dataframes need to be changed from object to float.

# %%
sat18['sat_participation_2018'] = (sat18['sat_participation_2018'].map(percent_to_float))

# %%
sat18.dtypes
# Out:
# state                      object
# sat_participation_2018    float64
# sat_rw_2018                 int64
# sat_math_2018               int64
# sat_total_2018              int64
# dtype: object

# %%
act18['act_participation_2018'] = act18['act_participation_2018'].map(percent_to_float)

# %%
act18.dtypes
# Out:
# state                      object
# act_participation_2018    float64
# act_composite_2018        float64
# dtype: object

# %%
sat18['state'].value_counts()
# Out:
# Washington              1
# Ohio                    1
# Arizona                 1
# Kentucky                1
# New Mexico              1
# New York                1
# Indiana                 1
# Hawaii                  1
# Wisconsin               1
# Minnesota               1
# Louisiana               1
# Vermont                 1
# Maine                   1
# District of Columbia    1
# Virginia                1
# Pennsylvania            1
# Nebraska                1
# Illinois                1
# Missouri                1
# Maryland                1
# Colorado                1
# South Carolina          1
# Alaska                  1
# Kansas                  1
# Iowa                    1
# Michigan                1
# Arkansas                1
# Idaho                   1
# Oregon                  1
# New Hampshire           1
# Mississippi             1
# Rhode Island            1
# South Dakota            1
# Tennessee               1
# Utah                    1
# ...

# %%
act18['state'].value_counts()
# Out:
# Maine                   2
# Ohio                    1
# Iowa                    1
# Arizona                 1
# Kentucky                1
# New Mexico              1
# New York                1
# Indiana                 1
# Wisconsin               1
# Minnesota               1
# Louisiana               1
# Vermont                 1
# Washington              1
# Oklahoma                1
# Virginia                1
# Pennsylvania            1
# Nebraska                1
# Illinois                1
# Missouri                1
# Maryland                1
# Colorado                1
# South Carolina          1
# Alaska                  1
# Kansas                  1
# District of columbia    1
# Georgia                 1
# Michigan                1
# Florida                 1
# Arkansas                1
# Oregon                  1
# New Hampshire           1
# Mississippi             1
# Nevada                  1
# South Dakota            1
# Tennessee               1
# ...

# %% [markdown]
# Here I wanted to check if there were any repeat rows since I knew ACT had 52 and SAT had 51.  I can see there is an extra Maine.

# %%
act18[act18['state'] == 'Maine']
# Out:
#     state  act_participation_2018  act_composite_2018
# 19  Maine                     7.0                24.0
# 20  Maine                     7.0                24.0

# %% [markdown]
# The rows are identical so I can safely delete one.

# %%
act18.drop(labels=19, inplace = True)

# %%
act18[act18['state'] == 'Maine']
# Out:
#     state  act_participation_2018  act_composite_2018
# 20  Maine                     7.0                24.0

# %%
act18.shape
# Out:
# (51, 3)

# %% [markdown]
# I also noticed District of columbia is partially lowercase in ACT.

# %%
act18['state'] = act18['state'].replace('District of columbia', 'District of Columbia')

# %%
act18[act18['state'] == 'District of Columbia']
# Out:
#                   state  act_participation_2018  act_composite_2018
# 8  District of Columbia                    32.0                23.6

# %% [markdown]
# #### Combine your 2017 and 2018 data into a single dataframe
# Joining on state names should work, assuming you formatted all your state names identically. Make sure none of your columns (other than state) have identical names. Do yourself a favor and decide if you're encoding participation rates as floats or integers and standardize this across your datasets.
#
# Save the contents of this merged dataframe as `final.csv`.
#
# **Use this combined dataframe for the remainder of the project**.

# %%
combined_2018 = pd.merge(sat18, act18, how='outer', on ='state')

# %%
combined_2018.head()
# Out:
#         state  sat_participation_2018  sat_rw_2018  sat_math_2018  \
# 0     Alabama                     6.0          595            571
# 1      Alaska                    43.0          562            544
# 2     Arizona                    29.0          577            572
# 3    Arkansas                     5.0          592            576
# 4  California                    60.0          540            536
#
#    sat_total_2018  act_participation_2018  act_composite_2018
# 0            1166                   100.0                19.1
# 1            1106                    33.0                20.8
# 2            1149                    66.0                19.2
# 3            1169                   100.0                19.4
# 4            1076                    27.0                22.7

# %%
combined_2018.describe()
# Out:
#        sat_participation_2018  sat_rw_2018  sat_math_2018  sat_total_2018  \
# count               51.000000    51.000000      51.000000       51.000000
# mean                45.745098   563.686275     556.235294     1120.019608
# std                 37.314256    47.502627      47.772623       94.155083
# min                  2.000000   480.000000     480.000000      977.000000
# 25%                  4.500000   534.500000     522.500000     1057.500000
# 50%                 52.000000   552.000000     544.000000     1098.000000
# 75%                 77.500000   610.500000     593.500000     1204.000000
# max                100.000000   643.000000     655.000000     1298.000000
#
#        act_participation_2018  act_composite_2018
# count               51.000000           51.000000
# mean                61.725490           21.496078
# std                 34.037085            2.111583
# min                  7.000000           17.700000
# ...

# %%
combined_2018.shape
# Out:
# (51, 7)

# %%
combined_2018['state'].sort_values()
# Out:
# 0                  Alabama
# 1                   Alaska
# 2                  Arizona
# 3                 Arkansas
# 4               California
# 5                 Colorado
# 6              Connecticut
# 7                 Delaware
# 8     District of Columbia
# 9                  Florida
# 10                 Georgia
# 11                  Hawaii
# 12                   Idaho
# 13                Illinois
# 14                 Indiana
# 15                    Iowa
# 16                  Kansas
# 17                Kentucky
# 18               Louisiana
# 19                   Maine
# 20                Maryland
# 21           Massachusetts
# 22                Michigan
# 23               Minnesota
# 24             Mississippi
# 25                Missouri
# 26                 Montana
# 27                Nebraska
# 28                  Nevada
# 29           New Hampshire
# 30              New Jersey
# 31              New Mexico
# 32                New York
# 33          North Carolina
# ...

# %%
final_df = pd.merge(combined_2017, combined_2018, how='outer', on ='state')

# %%
final_df.head()
# Out:
#         state  sat_participation_2017  sat_rw_2017  sat_math_2017  \
# 0     Alabama                     5.0          593            572
# 1      Alaska                    38.0          547            533
# 2     Arizona                    30.0          563            553
# 3    Arkansas                     3.0          614            594
# 4  California                    53.0          531            524
#
#    sat_total_2017  act_participation_2017  act_english_2017  act_math_2017  \
# 0            1165                   100.0              18.9           18.4
# 1            1080                    65.0              18.7           19.8
# 2            1116                    62.0              18.6           19.8
# 3            1208                   100.0              18.9           19.0
# 4            1055                    31.0              22.5           22.7
#
#    act_reading_2017  act_science_2017  act_composite_2017  \
# ...

# %%
final_df.shape
# Out:
# (51, 17)

# %%
final_df.describe()
# Out:
#        sat_participation_2017  sat_rw_2017  sat_math_2017  sat_total_2017  \
# count               51.000000    51.000000      51.000000       51.000000
# mean                39.803922   569.117647     556.882353     1126.098039
# std                 35.276632    45.666901      47.121395       92.494812
# min                  2.000000   482.000000     468.000000      950.000000
# 25%                  4.000000   533.500000     523.500000     1055.500000
# 50%                 38.000000   559.000000     548.000000     1107.000000
# 75%                 66.000000   613.000000     599.000000     1212.000000
# max                100.000000   644.000000     651.000000     1295.000000
#
#        act_participation_2017  act_english_2017  act_math_2017  \
# count               51.000000         51.000000      51.000000
# mean                65.254902         20.931373      21.182353
# std                 32.140842          2.353677       1.981989
# ...

# %%
final_df['state'].sort_values()
# Out:
# 0                  Alabama
# 1                   Alaska
# 2                  Arizona
# 3                 Arkansas
# 4               California
# 5                 Colorado
# 6              Connecticut
# 7                 Delaware
# 8     District of Columbia
# 9                  Florida
# 10                 Georgia
# 11                  Hawaii
# 12                   Idaho
# 13                Illinois
# 14                 Indiana
# 15                    Iowa
# 16                  Kansas
# 17                Kentucky
# 18               Louisiana
# 19                   Maine
# 20                Maryland
# 21           Massachusetts
# 22                Michigan
# 23               Minnesota
# 24             Mississippi
# 25                Missouri
# 26                 Montana
# 27                Nebraska
# 28                  Nevada
# 29           New Hampshire
# 30              New Jersey
# 31              New Mexico
# 32                New York
# 33          North Carolina
# ...

# %%
final_df.to_csv(path_or_buf='../data/final.csv')

# %% [markdown]
# ## Exploratory Data Analysis
#
#
# ### Summary Statistics
# Transpose the output of pandas `describe` method to create a quick overview of each numeric feature.

# %%
#Code: 

final_df.describe().T
# Out:
#                         count         mean        std    min      25%     50%  \
# sat_participation_2017   51.0    39.803922  35.276632    2.0     4.00    38.0
# sat_rw_2017              51.0   569.117647  45.666901  482.0   533.50   559.0
# sat_math_2017            51.0   556.882353  47.121395  468.0   523.50   548.0
# sat_total_2017           51.0  1126.098039  92.494812  950.0  1055.50  1107.0
# act_participation_2017   51.0    65.254902  32.140842    8.0    31.00    69.0
# act_english_2017         51.0    20.931373   2.353677   16.3    19.00    20.7
# act_math_2017            51.0    21.182353   1.981989   18.0    19.40    20.9
# act_reading_2017         51.0    22.013725   2.067271   18.1    20.45    21.8
# act_science_2017         51.0    21.450980   1.739353   18.2    19.95    21.3
# act_composite_2017       51.0    21.519608   2.020695   17.8    19.80    21.4
# sat_participation_2018   51.0    45.745098  37.314256    2.0     4.50    52.0
# ...

# %% [markdown]
# #### Manually calculate standard deviation
#
# $$\sigma = \sqrt{\frac{1}{n}\sum_{i=1}^n(x_i - \mu)^2}$$
#
# - Write a function to calculate standard deviation using the formula above

# %%
#code

def standard_deviation(array):
    summ = 0
    mean = array.mean()
    for x in array:
        difference = mean - x
        square = difference **2
        summ += square
    
    return np.sqrt(summ/(len(array) -1))
    

#got std formula from Matt Brem's lesson in pre-work

# %%
#test 
standard_deviation(final_df.sat_rw_2017.array)
# Out:
# 45.66690138768932

# %%
np.std(final_df.sat_rw_2017)
# Out:
# 45.21697020437866

# %%
new_dict = {}

for column in final_df.select_dtypes(exclude=['object']):
    new_dict[column] = standard_deviation(final_df[column].array)
    
print(new_dict)
# Out:
# {'sat_participation_2017': 35.276632270013046, 'sat_rw_2017': 45.66690138768932, 'sat_math_2017': 47.12139516560329, 'sat_total_2017': 92.49481172519046, 'act_participation_2017': 32.14084201588683, 'act_english_2017': 2.35367713980303, 'act_math_2017': 1.9819894936505533, 'act_reading_2017': 2.0672706264873146, 'act_science_2017': 1.7393530462812443, 'act_composite_2017': 2.020694891154341, 'sat_participation_2018': 37.31425633039196, 'sat_rw_2018': 47.50262737831599, 'sat_math_2018': 47.77262322095955, 'sat_total_2018': 94.15508275097599, 'act_participation_2018': 34.03708473496081, 'act_composite_2018': 2.111583366510896}

# %% [markdown]
# - Use a **dictionary comprehension** to apply your standard deviation function to each numeric column in the dataframe.  **No loops**
# - Assign the output to variable `sd` as a dictionary where:
#     - Each column name is now a key
#     - That standard deviation of the column is the value
#
# *Example Output :* `{'ACT_Math': 120, 'ACT_Reading': 120, ...}`

# %%
#Code:

sd = {column:standard_deviation(final_df[column].array) for column in final_df.select_dtypes(exclude=['object'])}

# %%
sd
# Out:
# {'sat_participation_2017': 35.276632270013046,
#  'sat_rw_2017': 45.66690138768932,
#  'sat_math_2017': 47.12139516560329,
#  'sat_total_2017': 92.49481172519046,
#  'act_participation_2017': 32.14084201588683,
#  'act_english_2017': 2.35367713980303,
#  'act_math_2017': 1.9819894936505533,
#  'act_reading_2017': 2.0672706264873146,
#  'act_science_2017': 1.7393530462812443,
#  'act_composite_2017': 2.020694891154341,
#  'sat_participation_2018': 37.31425633039196,
#  'sat_rw_2018': 47.50262737831599,
#  'sat_math_2018': 47.77262322095955,
#  'sat_total_2018': 94.15508275097599,
#  'act_participation_2018': 34.03708473496081,
#  'act_composite_2018': 2.111583366510896}

# %% [markdown]
# Do your manually calculated standard deviations match up with the output from pandas `describe`? What about numpy's `std` method?

# %% [markdown]
# Answer Yes! Very pleased to say my manually calculated standard deviation matches the pandas .decribe method exactly and it only off by .4 on np.std.

# %% [markdown]
# #### Investigate trends in the data
# Using sorting and/or masking (along with the `.head` method to not print our entire dataframe), consider the following questions:
#
# - Which states have the highest and lowest participation rates for the:
#     - 2017 SAT?
#     - 2018 SAT?
#     - 2017 ACT?
#     - 2018 ACT?
# - Which states have the highest and lowest mean total/composite scores for the:
#     - 2017 SAT?
#     - 2018 SAT?
#     - 2017 ACT?
#     - 2018 ACT?
# - Do any states with 100% participation on a given test have a rate change year-to-year?
# - Do any states show have >50% participation on *both* tests either year?
#
# Based on what you've just observed, have you identified any states that you're especially interested in? **Make a note of these and state *why* you think they're interesting**.
#
# **You should comment on your findings at each step in a markdown cell below your code block**. Make sure you include at least one example of sorting your dataframe by a column, and one example of using boolean filtering (i.e., masking) to select a subset of the dataframe.

# %%
final_df.columns
# Out:
# Index(['state', 'sat_participation_2017', 'sat_rw_2017', 'sat_math_2017',
#        'sat_total_2017', 'act_participation_2017', 'act_english_2017',
#        'act_math_2017', 'act_reading_2017', 'act_science_2017',
#        'act_composite_2017', 'sat_participation_2018', 'sat_rw_2018',
#        'sat_math_2018', 'sat_total_2018', 'act_participation_2018',
#        'act_composite_2018'],
#       dtype='object')

# %%
#code
final_df.sort_values(['sat_participation_2017'], ascending = False).head(15)
# Out:
#                    state  sat_participation_2017  sat_rw_2017  sat_math_2017  \
# 8   District of Columbia                   100.0          482            468
# 22              Michigan                   100.0          509            495
# 6            Connecticut                   100.0          530            512
# 7               Delaware                   100.0          503            492
# 29         New Hampshire                    96.0          532            520
# 19                 Maine                    95.0          513            499
# 12                 Idaho                    93.0          513            493
# 9                Florida                    83.0          520            497
# 21         Massachusetts                    76.0          555            551
# 39          Rhode Island                    71.0          539            524
# 30            New Jersey                    70.0          530            526
# ...

# %% [markdown]
# There were 13 states above the 75th percentile of participation in the 2017 SATs.  District of Columbia, Michigan, Connecticut and Delaware all had 100% student participation.

# %%
final_df.sort_values(['sat_participation_2017'], ascending = False).tail(15)
# Out:
#            state  sat_participation_2017  sat_rw_2017  sat_math_2017  \
# 42     Tennessee                     5.0          623            604
# 17      Kentucky                     4.0          631            616
# 16        Kansas                     4.0          632            628
# 18     Louisiana                     4.0          611            586
# 44          Utah                     3.0          624            614
# 49     Wisconsin                     3.0          642            649
# 25      Missouri                     3.0          640            631
# 41  South Dakota                     3.0          612            603
# 27      Nebraska                     3.0          629            625
# 23     Minnesota                     3.0          644            651
# 3       Arkansas                     3.0          614            594
# 50       Wyoming                     3.0          626            604
# 34  North Dakota                     2.0          635            621
# ...

# %% [markdown]
# There were 14 states with below 5% participation on the SATs in 2017: Iowa, Mississippi and North Dakota were the very lowest.

# %%
final_df.sort_values(['sat_total_2017'], ascending = False).head(15)
# Out:
#            state  sat_participation_2017  sat_rw_2017  sat_math_2017  \
# 23     Minnesota                     3.0          644            651
# 49     Wisconsin                     3.0          642            649
# 15          Iowa                     2.0          641            635
# 25      Missouri                     3.0          640            631
# 16        Kansas                     4.0          632            628
# 34  North Dakota                     2.0          635            621
# 27      Nebraska                     3.0          629            625
# 17      Kentucky                     4.0          631            616
# 24   Mississippi                     2.0          634            607
# 44          Utah                     3.0          624            614
# 50       Wyoming                     3.0          626            604
# 42     Tennessee                     5.0          623            604
# 41  South Dakota                     3.0          612            603
# ...

# %% [markdown]
# Only 15 states had total average SAT scores higher than 1200.  Minnesota, Wisconsin and Iowa had the highest 2017 SAT scores.

# %%
final_df.sort_values(['sat_total_2017']).head(15)
# Out:
#                    state  sat_participation_2017  sat_rw_2017  sat_math_2017  \
# 8   District of Columbia                   100.0          482            468
# 7               Delaware                   100.0          503            492
# 12                 Idaho                    93.0          513            493
# 22              Michigan                   100.0          509            495
# 19                 Maine                    95.0          513            499
# 9                Florida                    83.0          520            497
# 43                 Texas                    62.0          513            507
# 6            Connecticut                   100.0          530            512
# 36              Oklahoma                     7.0          530            517
# 10               Georgia                    61.0          535            515
# 32              New York                    67.0          528            523
# ...

# %% [markdown]
# District of Comlumbia, Delaware and Idaho had the lowest average total SAT scores for 2017.  There were 13 states in the bottom quartile.

# %%
final_df[final_df['act_participation_2017'] >= 90.0]
# Out:
#              state  sat_participation_2017  sat_rw_2017  sat_math_2017  \
# 0          Alabama                     5.0          593            572
# 3         Arkansas                     3.0          614            594
# 5         Colorado                    11.0          606            595
# 11          Hawaii                    55.0          544            541
# 13        Illinois                     9.0          559            556
# 17        Kentucky                     4.0          631            616
# 18       Louisiana                     4.0          611            586
# 23       Minnesota                     3.0          644            651
# 24     Mississippi                     2.0          634            607
# 25        Missouri                     3.0          640            631
# 26         Montana                    10.0          605            591
# 28          Nevada                    26.0          563            553
# ...

# %%
final_df['act_participation_2017'].value_counts(normalize=True).head()
# Out:
# 100.0    0.333333
# 29.0     0.098039
# 31.0     0.058824
# 18.0     0.039216
# 73.0     0.039216
# Name: act_participation_2017, dtype: float64

# %% [markdown]
# There were 20 states with 90% or greater ACT participation in 2017 with 33% of states having 100% participation.

# %%
final_df['act_participation_2017'].value_counts(normalize=True).tail()
# Out:
# 40.0    0.019608
# 23.0    0.019608
# 21.0    0.019608
# 80.0    0.019608
# 8.0     0.019608
# Name: act_participation_2017, dtype: float64

# %%
final_df[final_df['act_participation_2017'] <= 25.0]
# Out:
#             state  sat_participation_2017  sat_rw_2017  sat_math_2017  \
# 7        Delaware                   100.0          503            492
# 19          Maine                    95.0          513            499
# 29  New Hampshire                    96.0          532            520
# 38   Pennsylvania                    65.0          540            531
# 39   Rhode Island                    71.0          539            524
#
#     sat_total_2017  act_participation_2017  act_english_2017  act_math_2017  \
# 7              996                    18.0              24.1           23.4
# 19            1012                     8.0              24.2           24.0
# 29            1052                    18.0              25.4           25.1
# 38            1071                    23.0              23.4           23.4
# 39            1062                    21.0              24.0           23.3
#
#     act_reading_2017  act_science_2017  act_composite_2017  \
# ...

# %% [markdown]
# Only 5 states had 25% or lower participation on the 2017 ACTs.

# %%
final_df.sort_values(['act_composite_2017'], ascending = False).head(15)
# Out:
#                    state  sat_participation_2017  sat_rw_2017  sat_math_2017  \
# 29         New Hampshire                    96.0          532            520
# 21         Massachusetts                    76.0          555            551
# 6            Connecticut                   100.0          530            512
# 19                 Maine                    95.0          513            499
# 8   District of Columbia                   100.0          482            468
# 32              New York                    67.0          528            523
# 22              Michigan                   100.0          509            495
# 7               Delaware                   100.0          503            492
# 39          Rhode Island                    71.0          539            524
# 30            New Jersey                    70.0          530            526
# 46              Virginia                    65.0          561            541
# ...

# %% [markdown]
# Top 3 ACT composite scores for 2017 were New Hampshire, Massachusetts, and Connecticut.

# %%
final_df.sort_values(['act_composite_2017']).head(10)
# Out:
#              state  sat_participation_2017  sat_rw_2017  sat_math_2017  \
# 28          Nevada                    26.0          563            553
# 24     Mississippi                     2.0          634            607
# 40  South Carolina                    50.0          543            521
# 11          Hawaii                    55.0          544            541
# 33  North Carolina                    49.0          546            535
# 0          Alabama                     5.0          593            572
# 3         Arkansas                     3.0          614            594
# 36        Oklahoma                     7.0          530            517
# 18       Louisiana                     4.0          611            586
# 2          Arizona                    30.0          563            553
#
#     sat_total_2017  act_participation_2017  act_english_2017  act_math_2017  \
# 28            1116                   100.0              16.3           18.0
# ...

# %% [markdown]
# Nevada, Mississippi and South Carolina scored the lowest compsite numbers on the 2017 ACTs.

# %%
final_df[final_df['sat_participation_2018'] >= 90.0]
# Out:
#                    state  sat_participation_2017  sat_rw_2017  sat_math_2017  \
# 5               Colorado                    11.0          606            595
# 6            Connecticut                   100.0          530            512
# 7               Delaware                   100.0          503            492
# 8   District of Columbia                   100.0          482            468
# 12                 Idaho                    93.0          513            493
# 13              Illinois                     9.0          559            556
# 19                 Maine                    95.0          513            499
# 22              Michigan                   100.0          509            495
# 29         New Hampshire                    96.0          532            520
# 39          Rhode Island                    71.0          539            524
#
#     sat_total_2017  act_participation_2017  act_english_2017  act_math_2017  \
# ...

# %% [markdown]
# There were 10 states with 90% or greater SAT participation in 2018 including Colorado and Illinois whose numbers participation was in the bottom quartile the year prior.

# %%
final_df[final_df['sat_participation_2018'] <= 50.0]
# Out:
#             state  sat_participation_2017  sat_rw_2017  sat_math_2017  \
# 0         Alabama                     5.0          593            572
# 1          Alaska                    38.0          547            533
# 2         Arizona                    30.0          563            553
# 3        Arkansas                     3.0          614            594
# 15           Iowa                     2.0          641            635
# 16         Kansas                     4.0          632            628
# 17       Kentucky                     4.0          631            616
# 18      Louisiana                     4.0          611            586
# 23      Minnesota                     3.0          644            651
# 24    Mississippi                     2.0          634            607
# 25       Missouri                     3.0          640            631
# 26        Montana                    10.0          605            591
# ...

# %% [markdown]
# Number of states below 5% participation stayed the same for 2018 at 14. North Dakota had the lowest.

# %%
final_df.sort_values(['sat_total_2018'], ascending = False ).head(10)
# Out:
#            state  sat_participation_2017  sat_rw_2017  sat_math_2017  \
# 23     Minnesota                     3.0          644            651
# 49     Wisconsin                     3.0          642            649
# 34  North Dakota                     2.0          635            621
# 15          Iowa                     2.0          641            635
# 16        Kansas                     4.0          632            628
# 25      Missouri                     3.0          640            631
# 50       Wyoming                     3.0          626            604
# 27      Nebraska                     3.0          629            625
# 17      Kentucky                     4.0          631            616
# 41  South Dakota                     3.0          612            603
#
#     sat_total_2017  act_participation_2017  act_english_2017  act_math_2017  \
# 23            1295                   100.0              20.4           21.5
# ...

# %% [markdown]
# Minnesota, Wisconsin and North Dakota had the top 3 highest SAT scores for 2018.

# %%
final_df.sort_values(['sat_total_2018']).head(15)
# Out:
#                    state  sat_participation_2017  sat_rw_2017  sat_math_2017  \
# 8   District of Columbia                   100.0          482            468
# 7               Delaware                   100.0          503            492
# 48         West Virginia                    14.0          558            528
# 12                 Idaho                    93.0          513            493
# 44                  Utah                     3.0          624            614
# 11                Hawaii                    55.0          544            541
# 22              Michigan                   100.0          509            495
# 19                 Maine                    95.0          513            499
# 39          Rhode Island                    71.0          539            524
# 13              Illinois                     9.0          559            556
# 5               Colorado                    11.0          606            595
# ...

# %% [markdown]
# District of Columbia was in the bottom 3 SAT scores for another year in a row.

# %%
final_df[final_df['act_participation_2018'] >= 90.0]
# Out:
#              state  sat_participation_2017  sat_rw_2017  sat_math_2017  \
# 0          Alabama                     5.0          593            572
# 3         Arkansas                     3.0          614            594
# 17        Kentucky                     4.0          631            616
# 18       Louisiana                     4.0          611            586
# 23       Minnesota                     3.0          644            651
# 24     Mississippi                     2.0          634            607
# 25        Missouri                     3.0          640            631
# 26         Montana                    10.0          605            591
# 27        Nebraska                     3.0          629            625
# 28          Nevada                    26.0          563            553
# 33  North Carolina                    49.0          546            535
# 34    North Dakota                     2.0          635            621
# ...

# %% [markdown]
# There were 19 states with 90% or greater participation on 2018 ACTs

# %%
final_df[final_df['act_participation_2018'] <= 50.0].head()
# Out:
#          state  sat_participation_2017  sat_rw_2017  sat_math_2017  \
# 1       Alaska                    38.0          547            533
# 4   California                    53.0          531            524
# 5     Colorado                    11.0          606            595
# 6  Connecticut                   100.0          530            512
# 7     Delaware                   100.0          503            492
#
#    sat_total_2017  act_participation_2017  act_english_2017  act_math_2017  \
# 1            1080                    65.0              18.7           19.8
# 4            1055                    31.0              22.5           22.7
# 5            1201                   100.0              20.1           20.3
# 6            1041                    31.0              25.5           24.6
# 7             996                    18.0              24.1           23.4
#
#    act_reading_2017  act_science_2017  act_composite_2017  \
# ...

# %% [markdown]
# Almost 50% of states, had 50% or less 2018 ACT participation.

# %%
final_df.sort_values(['act_composite_2018'], ascending = False ).head(10)
# Out:
#             state  sat_participation_2017  sat_rw_2017  sat_math_2017  \
# 6     Connecticut                   100.0          530            512
# 21  Massachusetts                    76.0          555            551
# 29  New Hampshire                    96.0          532            520
# 32       New York                    67.0          528            523
# 22       Michigan                   100.0          509            495
# 39   Rhode Island                    71.0          539            524
# 45        Vermont                    60.0          562            551
# 19          Maine                    95.0          513            499
# 13       Illinois                     9.0          559            556
# 5        Colorado                    11.0          606            595
#
#     sat_total_2017  act_participation_2017  act_english_2017  act_math_2017  \
# 6             1041                    31.0              25.5           24.6
# ...

# %% [markdown]
# Connecticut, Massachusetts and New Hampshire scored the highest on the ACT for 2018.

# %%
final_df.sort_values(['act_composite_2018']).head(5)
# Out:
#              state  sat_participation_2017  sat_rw_2017  sat_math_2017  \
# 28          Nevada                    26.0          563            553
# 40  South Carolina                    50.0          543            521
# 24     Mississippi                     2.0          634            607
# 11          Hawaii                    55.0          544            541
# 0          Alabama                     5.0          593            572
#
#     sat_total_2017  act_participation_2017  act_english_2017  act_math_2017  \
# 28            1116                   100.0              16.3           18.0
# 40            1064                   100.0              17.5           18.6
# 24            1242                   100.0              18.2           18.1
# 11            1085                    90.0              17.8           19.2
# 0             1165                   100.0              18.9           18.4
#
#     act_reading_2017  act_science_2017  act_composite_2017  \
# ...

# %% [markdown]
# All but one of the bottom 5 ACT scores came from states with 100% participation. Nevada was the worst.

# %%
final_df[(final_df['sat_participation_2017'] == 100.0) | (final_df['sat_participation_2018'] == 100.0)]
# Out:
#                    state  sat_participation_2017  sat_rw_2017  sat_math_2017  \
# 5               Colorado                    11.0          606            595
# 6            Connecticut                   100.0          530            512
# 7               Delaware                   100.0          503            492
# 8   District of Columbia                   100.0          482            468
# 12                 Idaho                    93.0          513            493
# 22              Michigan                   100.0          509            495
#
#     sat_total_2017  act_participation_2017  act_english_2017  act_math_2017  \
# 5             1201                   100.0              20.1           20.3
# 6             1041                    31.0              25.5           24.6
# 7              996                    18.0              24.1           23.4
# 8              950                    32.0              24.4           23.5
# ...

# %% [markdown]
# Connecticut, Delaware and Michigan had 100% SAT participation both 2017 and 2018. DC had 100% participation in 2017 but went down to 92% in 2018. Their total scores went up when participation went down.  Colorado had the biggest jump from only 11% participation in 2017 to 100% in 2018, but score dropped about 200 points with the increase in participation.

# %%
final_df[(final_df['act_participation_2017'] == 100.0) | (final_df['act_participation_2018'] == 100.0)].head()
# Out:
#         state  sat_participation_2017  sat_rw_2017  sat_math_2017  \
# 0     Alabama                     5.0          593            572
# 3    Arkansas                     3.0          614            594
# 5    Colorado                    11.0          606            595
# 17   Kentucky                     4.0          631            616
# 18  Louisiana                     4.0          611            586
#
#     sat_total_2017  act_participation_2017  act_english_2017  act_math_2017  \
# 0             1165                   100.0              18.9           18.4
# 3             1208                   100.0              18.9           19.0
# 5             1201                   100.0              20.1           20.3
# 17            1247                   100.0              19.6           19.4
# 18            1198                   100.0              19.4           18.8
#
#     act_reading_2017  act_science_2017  act_composite_2017  \
# ...

# %% [markdown]
# Colorado had the opposite spike for ACTs with 100% participation in 2017 and only 30% in 2018 and composite score went up. Nebraska and Ohio went up to 100% but the score didn't change very much.

# %%
final_df[(final_df['act_participation_2017'] > 50.0) & (final_df['sat_participation_2017'] > 50.0)]
# Out:
#       state  sat_participation_2017  sat_rw_2017  sat_math_2017  \
# 9   Florida                    83.0          520            497
# 10  Georgia                    61.0          535            515
# 11   Hawaii                    55.0          544            541
#
#     sat_total_2017  act_participation_2017  act_english_2017  act_math_2017  \
# 9             1017                    73.0              19.0           19.4
# 10            1050                    55.0              21.0           20.9
# 11            1085                    90.0              17.8           19.2
#
#     act_reading_2017  act_science_2017  act_composite_2017  \
# 9               21.0              19.4                19.8
# 10              22.0              21.3                21.4
# 11              19.2              19.3                19.0
#
#     sat_participation_2018  sat_rw_2018  sat_math_2018  sat_total_2018  \
# 9                     56.0          550            549            1099
# ...

# %%
final_df[(final_df['act_participation_2018'] > 50.0) & (final_df['sat_participation_2018'] > 50.0)]
# Out:
#              state  sat_participation_2017  sat_rw_2017  sat_math_2017  \
# 9          Florida                    83.0          520            497
# 10         Georgia                    61.0          535            515
# 11          Hawaii                    55.0          544            541
# 33  North Carolina                    49.0          546            535
# 40  South Carolina                    50.0          543            521
#
#     sat_total_2017  act_participation_2017  act_english_2017  act_math_2017  \
# 9             1017                    73.0              19.0           19.4
# 10            1050                    55.0              21.0           20.9
# 11            1085                    90.0              17.8           19.2
# 33            1081                   100.0              17.8           19.3
# 40            1064                   100.0              17.5           18.6
#
#     act_reading_2017  act_science_2017  act_composite_2017  \
# ...

# %% [markdown]
# Only 3 states, Florida, Georgia and Hawaii, had participation over 50% for both SAT and ACT tests in 2017.  North and South Carolina joined them in 2018. Total and Composite scores for all were below average.

# %% [markdown]
# ## Visualize the data
#
# There's not a magic bullet recommendation for the right number of plots to understand a given dataset, but visualizing your data is *always* a good idea. Not only does it allow you to quickly convey your findings (even if you have a non-technical audience), it will often reveal trends in your data that escaped you when you were looking only at numbers.
#
# Some recommendations on plotting:
# - Plots have titles
# - Plots have axis labels
# - Plots have appropriate tick labels
# - All text is legible in a plot
# - Plots demonstrate meaningful and valid relationships
# - Plots are interpreted to aid understanding
#
# There is such a thing as too many plots, and there are a *lot* of bad plots. You might make some! (But hopefully not with the guided prompts below).

# %% [markdown]
# #### Use Seaborn's heatmap with pandas `.corr()` to visualize correlations between all numeric features
#
# Heatmaps are generally not appropriate for presentations, and should often be excluded from reports as they can be visually overwhelming. **However**, they can be extremely useful in identify relationships of potential interest (as well as identifying potential collinearity before modeling).
#
# *example*:
# ```python
# sns.heatmap(df.corr())
# ```
#
# Please take time to format your output, adding a title. Look through some of the additional arguments and options. (Axis labels aren't really necessary, as long as the title is informative).

# %%
plt.figure(figsize = (12, 12))
ax = plt.axes()
ax.set_title('Correlation between SAT & ACT scores 2017-2018', fontsize = 20)

sns.heatmap(final_df.corr(), cmap = "coolwarm", annot = True);

#code used from Riley Dallas lecture

# %% [markdown]
# #### Define a custom function to subplot histograms
#
# We have data for two tests for two years. We only have composite (and not subtest scores) for the 2018 ACT. We should write a function that will take the names of 2+ columns and subplot histograms. While you can use pandas plotting or Seaborn here, matplotlib gives you greater control over all aspects of your plots.
#
# [Helpful Link for Plotting Multiple Figures](https://matplotlib.org/users/pyplot_tutorial.html#working-with-multiple-figures-and-axes)
#
# Here's some starter code:

# %%
def subplot_histograms(dataframe, list_of_columns, list_of_titles, list_of_xlabels):
    
    nrows = int(np.ceil(len(list_of_columns)/2)) # Makes sure you have enough rows
    
    fig, ax = plt.subplots(nrows=nrows, ncols=2, figsize=(12, 8)) # You'll want to specify your figsize
    
    ax = ax.ravel() # Ravel turns a matrix into a vector, which is easier to iterate
    
    for i, column in enumerate(list_of_columns): # Gives us an index value to get into all our lists
        ax[i].hist(dataframe[column])
        ax[i].set_title(list_of_titles[i])
        ax[i].set_ylabel('# of States')
        
        # feel free to add more settings
    
    # Set titles, labels, etc here for each subplot

# %% [markdown]
# #### Plot and interpret histograms
# For each of the following:
# - Participation rates for SAT & ACT
# - Math scores for SAT & ACT
# - Reading/verbal scores for SAT & ACT

# %%
subplot_histograms(dataframe=final_df, 
                   list_of_columns = ['sat_participation_2017', 'sat_participation_2018', 'act_participation_2017', 'act_participation_2018'],
                   list_of_titles = ["SAT_Participation_2017", 'SAT_Participation_2018', 'ACT_Participation_2017', 'ACT_Participation_2018'], 
                   list_of_xlabels = ["Particpation %", "Particpation %", "Particpation %", "Particpation %"]
                  )

plt.xlabel('Participation %');

# %% [markdown]
# The above histogram shows participation rates increased for SATs from 2017 to 2018.  It looks likes participation had some changes for the ACTs as well but stayed alost the same. Overall, the ACTs had higher participation rates than SAT both years.

# %%
# Code

subplot_histograms(dataframe=final_df, 
                   list_of_columns = ['sat_math_2017', 'sat_math_2018', 'act_math_2017'],
                   list_of_titles = ["SAT_Math_2017", 'SAT_Math_2018', 'ACT_Math_2017'], 
                   list_of_xlabels = ["Math_Score", "Math_Score", "Math_Score"]
                  )

# %% [markdown]
# The scores by subject do not look to be normally distributed.

# %%
subplot_histograms(dataframe=final_df, 
                   list_of_columns = ['sat_rw_2017', 'sat_rw_2018', 'act_reading_2017', 'act_english_2017', ],
                   list_of_titles = ["SAT_Reading_Writing_2017", 'SAT_Reading_Writing_2018', 'ACT_Reading_2017', 'ACT_English_2017'], 
                       list_of_xlabels = ["Average_Score", "Average_Score", "Average_Score", 'Average_Score']
                  )

# %%
final_df.hist();

# %% [markdown]
# #### Plot and interpret scatter plots
#
# For each of the following:
# - SAT vs. ACT math scores for 2017
# - SAT vs. ACT verbal/reading scores for 2017
# - SAT vs. ACT total/composite scores for 2017
# - Total scores for SAT 2017 vs. 2018
# - Composite scores for ACT 2017 vs. 2018
#
# Plot the two variables against each other using matplotlib or Seaborn
#
# Your plots should show:
# - Two clearly labeled axes
# - A proper title
# - Using colors and symbols that are clear and unmistakable
#
# **Feel free to write a custom function, and subplot if you'd like.** Functions save both time and space.

# %%
plt.figure(figsize=(10, 5))

plt.scatter(final_df['sat_math_2017'],
           final_df['act_math_2017'], 
           alpha = 1)  
 
plt.title("SAT vs. ACT math scores for 2017", fontsize = 20)
plt.ylabel("ACT Math Scores", fontsize = 15)
plt.xlabel("SAT Math Scores", fontsize = 15);

#code adapted from Principles of Data Visualization lecture.

# %%
plt.figure(figsize=(10, 5))

plt.scatter(final_df['sat_rw_2017'],
           final_df['act_reading_2017'], 
           alpha = 1)  
 
plt.title("SAT vs. ACT verbal/reading scores for 2017", fontsize = 20)
plt.ylabel("ACT Reading Scores", fontsize = 15)
plt.xlabel("SAT Reading-Writing Scores", fontsize = 15);

# %%
plt.figure(figsize=(10, 5))

plt.scatter(final_df['sat_rw_2017'],
           final_df['act_english_2017'], 
           alpha = 1)  
 
plt.title("SAT vs. ACT verbal/reading scores for 2017", fontsize = 20)
plt.ylabel("ACT English Scores", fontsize = 15)
plt.xlabel("SAT Reading-Writing Scores", fontsize = 15);

# %%
plt.figure(figsize=(10, 5))

plt.scatter(final_df['sat_total_2017'],
           final_df['act_composite_2017'], 
           alpha = 1)  
 
plt.title("SAT vs. ACT total/composite scores for 2017", fontsize = 20)
plt.ylabel("ACT Average Composite Scores", fontsize = 15)
plt.xlabel("SAT Average Total Scores", fontsize = 15);

# %%
plt.figure(figsize=(10, 5))

plt.scatter(final_df['sat_total_2018'],
           final_df['act_composite_2018'], 
           alpha = 1)  
 
plt.title("SAT vs. ACT total/composite scores for 2018", fontsize = 20)
plt.ylabel("ACT Average Composite Scores", fontsize = 15)
plt.xlabel("SAT Average Total Scores", fontsize = 15);

# %% [markdown]
# I do not feel like the scatter plot comparing ACT and SAT scores are very helpful.  They are hard to read and do not provide an easy to understand conclusion.

# %%
plt.figure(figsize=(10, 5))

plt.scatter(final_df['sat_total_2017'],
           final_df['sat_total_2018'], 
           alpha = 1)  
 
plt.title("Total scores for SAT 2017 vs. 2018", fontsize = 20)
plt.ylabel("Average Total SAT Scores 2018", fontsize = 15)
plt.xlabel("Average Total SAT Scores 2017", fontsize = 15);

# %% [markdown]
# The above scatter plot shows Average Total SAT scores stayed approximately the same from 2017 to 2018 in the majority of states.  There are a few outliers where it varied greatly.

# %%
plt.figure(figsize=(10, 5))

plt.scatter(final_df['act_composite_2017'],
           final_df['act_composite_2018'], 
           alpha = 1)  
 
plt.title("Total scores for ACT 2017 vs. 2018", fontsize = 20)
plt.ylabel("Average Composite ACT Scores 2018", fontsize = 15)
plt.xlabel("Average Composite ACT Scores 2017", fontsize = 15);

# %% [markdown]
# The above scatter plot shows Average ACT Composite Scores stayed about the same from 2017 to 2018 as well.  There were only about 2 outliers that increased greatly.

# %% [markdown]
# #### Plot and interpret boxplots
#
# For each numeric variable in the dataframe create a boxplot using Seaborn. Boxplots demonstrate central tendency and spread in variables. In a certain sense, these are somewhat redundant with histograms, but you may be better able to identify clear outliers or differences in IQR, etc.
#
# Multiple values can be plotted to a single boxplot as long as they are of the same relative scale (meaning they have similar min/max values).
#
# Each boxplot should:
# - Only include variables of a similar scale
# - Have clear labels for each variable
# - Have appropriate titles and labels

# %%
# Code

sns.boxplot(data=final_df[['sat_math_2017', 'sat_math_2018']], orient = 'h' 
           
).set(
xlabel='Average scores',
title = 'SAT Math Scores 2017 V 2018');

# %% [markdown]
# According to this box plot, the national average of SAT Math scores stayed pretty much the same from 2017 to 2018.

# %%
sns.boxplot(data=final_df[['sat_rw_2017', 'sat_rw_2018']], orient = 'h' 
           
).set(
xlabel='Average scores',
title = 'SAT Reading/Writing Scores 2017 V 2018');

# %% [markdown]
# According to the above box plot, the national average of SAT Reading/Writing scores did not change much from 2017 to 2018.

# %%
sns.boxplot(data=final_df[['sat_participation_2017','act_participation_2017', 'sat_participation_2018', 'act_participation_2018']], 
            orient = 'h' 
).set(
xlabel='Participation %',
title = 'SAT v ACT Participation, 2017 v 2018');

# %% [markdown]
# This boxplot shows overall participation for the SATs was lower than the ACTs both years.

# %%
sns.boxplot(data=final_df[['sat_total_2017', 'sat_total_2018']], 
            orient = 'h' 
).set(
xlabel='Average Total Scores',
title = 'SAT Total Scores 2017 v 2018');

# %% [markdown]
# This box plot shows there was not a lot of variation between 2017 and 2018 total SAT scores.

# %%
sns.boxplot(data=final_df[['act_composite_2017', 'act_composite_2018']], 
            orient = 'h' 
).set(
xlabel='Average Composite Scores',
title = 'ACT Composite Scores 2017 v 2018');

# %% [markdown]
# This box plot shows there was not a lot of variation between average 2017 and 2018 composite ACT scores.

# %% [markdown]
# ## Descriptive and Inferential Statistics

# %% [markdown]
# #### Summarizing Distributions
#
# Above, we used pandas `describe` to provide quick summary statistics of our numeric columns. We also demonstrated many visual relationships.
#
# As data scientists, having a complete understanding of data is imperative prior to modeling.
#
# While we will continue to build our analytic tools, we know that measures of *central tendency*, *spread*, and *shape/skewness* provide a quick summary of distributions.
#
# For each variable in your data, summarize the underlying distributions (in words & statistics)
#  - Be thorough in your verbal description of these distributions.
#  - Be sure to back up these summaries with statistics.

# %%
final_df.describe().T
# Out:
#                         count         mean        std    min      25%     50%  \
# sat_participation_2017   51.0    39.803922  35.276632    2.0     4.00    38.0
# sat_rw_2017              51.0   569.117647  45.666901  482.0   533.50   559.0
# sat_math_2017            51.0   556.882353  47.121395  468.0   523.50   548.0
# sat_total_2017           51.0  1126.098039  92.494812  950.0  1055.50  1107.0
# act_participation_2017   51.0    65.254902  32.140842    8.0    31.00    69.0
# act_english_2017         51.0    20.931373   2.353677   16.3    19.00    20.7
# act_math_2017            51.0    21.182353   1.981989   18.0    19.40    20.9
# act_reading_2017         51.0    22.013725   2.067271   18.1    20.45    21.8
# act_science_2017         51.0    21.450980   1.739353   18.2    19.95    21.3
# act_composite_2017       51.0    21.519608   2.020695   17.8    19.80    21.4
# sat_participation_2018   51.0    45.745098  37.314256    2.0     4.50    52.0
# ...

# %% [markdown]
# Answers:
#
# SAT Participation Data is widely dispersed and skewed to the right with a high of 100% and a min of 2%. These stay the same from 2017 to 2018, however, the mean and median increase by a litte more than 20% which means the distribution also shifted.
#
# SAT Scores (Reading/Writing, Math &Total) distribution stays consistent from one year to another but is also widely dispersed from min to max.
#
# ACT Participation Data are widely dispersed and skewed left.  The 75% stands out as unusual for both years because it is the same at the max. The mean stays about the same.
#
# ACT Scores have the lowest standard deviation of all the variable and the mean stays consistent.

# %% [markdown]
# #### We generally assume that data we sample from a population will be normally distributed. Do we observe this trend?

# %% [markdown]
# Answer: No, we do not see normal distribution anywhere in this data. This holds true for all test scores and participation rates.

# %% [markdown]
# Does This Assumption Hold for:
#     - Math
#     - Reading
#     - Rates
# Explain your answers for each distribution and how you think this will affect estimates made from these data.

# %% [markdown]
# Answer: There are too many outside factor affecting test score outcomes. Like test prep books and tutors or courses for students who are taking it seriously for example.  Participation distributions is also skewed becuase the tests are required in some states.
#
# According to the Washington Post, critics of these tests have been complaining of these factors for a while, noting money can play a big role in a child's sucess as well. In states where the test is not mandatory it may be too expensive for some to take or they may not have all the same resources to for good studying.
#
# https://www.washingtonpost.com/education/2019/03/19/is-it-finally-time-get-rid-sat-act-college-admissions-tests/?noredirect=on&utm_term=.67e2f1579130

# %% [markdown]
# #### Estimate Limits of Data
#
# Suppose we only seek to understand the relationship between SAT and ACT participation rates in 2017.
#
# ##### Does it make sense to conduct statistical inference given these data specifically?
#
# Why or why not?
#
# *(think about granularity, aggregation, the relationships between populations size & rates...consider the actual populations these data describe in answering this question)*

# %% [markdown]
# Answer: I do think it makes sense to compare participation rates between the two tests. It seems like there is a clear correlation between states having a high participation for one test being very low for the other.  It would be hepful to find out what exactly is causing students to choose one over the other.

# %% [markdown]
# ##### Is it appropriate to compare *these* specific SAT and ACT math scores?
#
# Why or why not?

# %% [markdown]
# Answer: No, I do no think it is appropriate to compare SAT and ACT Math scores because they are graded on a completely different scale and points system.

# %% [markdown]
# #### Statistical Evaluation of Distributions
#
# **If you feel it's appropriate**, using methods we discussed in class, run hypothesis tests to compare variables of interest in our dataset.

# %% [markdown]
# ## Outside Research

# %% [markdown]
# Based upon your observations, choose **three** states that demonstrate interesting trends in their SAT and/or ACT participation rates. Spend some time doing outside research on state policies that might influence these rates, and summarize your findings below. **Feel free to go back and create new plots that highlight these states of interest**. If you bring in any outside tables or charts, make sure you are explicit about having borrowed them. If you quote any text, make sure that it renders as being quoted. (Make sure that you cite your sources -- check with you local instructor for citation preferences).

# %% [markdown]
# I chose Colorado, North Dakota and District of Columbia.
# Colorado is interesting to me because the SAT participation grew from 11% to 100% from 2017 to 2018 when the tests become mandatory (https://blog.prepscholar.com/which-states-require-the-sat ). Average total score dropped from 1200 to 1025. Consequently, the ACT numbers reversed. It's participation dropped from 100% to 30% which caused the average composite score to increase from 20.3 to 23.9.
#
# The required test for Colorado students changed due to "hard-fought testing reform legistlation" and to align with the core curriculum.
# https://www.chalkbeat.org/posts/co/2015/12/23/goodbye-act-hello-sat-a-significant-change-for-colorado-high-schoolers/

# %%
final_df.loc[final_df['state'] == 'Colorado']
# Out:
#       state  sat_participation_2017  sat_rw_2017  sat_math_2017  \
# 5  Colorado                    11.0          606            595
#
#    sat_total_2017  act_participation_2017  act_english_2017  act_math_2017  \
# 5            1201                   100.0              20.1           20.3
#
#    act_reading_2017  act_science_2017  act_composite_2017  \
# 5              21.2              20.9                20.8
#
#    sat_participation_2018  sat_rw_2018  sat_math_2018  sat_total_2018  \
# 5                   100.0          519            506            1025
#
#    act_participation_2018  act_composite_2018
# 5                    30.0                23.9

# %% [markdown]
# According to our data, North Dakota had the lowest SAT participation rates both years, but one of the highest scores.
#
# The ACT test is mandatory for high school juniors to take in North Dakota and free to take.
# https://blog.prepscholar.com/which-states-require-the-act-full-list-and-advice
#
# Even though the ACT scores for ND are lower than the national average, the fact that the test is free provides many opportunities to low income kids who may not have been able to take it otherwise. https://www.nd.gov/dpi/SchoolStaff/assessment/act_workkeys/

# %%
final_df.loc[final_df['state'] == 'North Dakota']
# Out:
#            state  sat_participation_2017  sat_rw_2017  sat_math_2017  \
# 34  North Dakota                     2.0          635            621
#
#     sat_total_2017  act_participation_2017  act_english_2017  act_math_2017  \
# 34            1256                    98.0              19.0           20.4
#
#     act_reading_2017  act_science_2017  act_composite_2017  \
# 34              20.5              20.6                20.3
#
#     sat_participation_2018  sat_rw_2018  sat_math_2018  sat_total_2018  \
# 34                     2.0          640            643            1283
#
#     act_participation_2018  act_composite_2018
# 34                    98.0                20.3

# %% [markdown]
# District of Columbia intrigued me because of its 100% SAT participation but extremely low SAT scores.  I was surprised to find out the test is actually not mandatory there but it is free so that is great that juniors are taking advantage of the opportunity. https://blog.prepscholar.com/which-states-require-the-sat

# %%
final_df.loc[final_df['state'] == 'District of Columbia']
# Out:
#                   state  sat_participation_2017  sat_rw_2017  sat_math_2017  \
# 8  District of Columbia                   100.0          482            468
#
#    sat_total_2017  act_participation_2017  act_english_2017  act_math_2017  \
# 8             950                    32.0              24.4           23.5
#
#    act_reading_2017  act_science_2017  act_composite_2017  \
# 8              24.9              23.5                24.2
#
#    sat_participation_2018  sat_rw_2018  sat_math_2018  sat_total_2018  \
# 8                    92.0          497            480             977
#
#    act_participation_2018  act_composite_2018
# 8                    32.0                23.6

# %%
final_df.loc[final_df['state'] == 'California']
# Out:
#         state  sat_participation_2017  sat_rw_2017  sat_math_2017  \
# 4  California                    53.0          531            524
#
#    sat_total_2017  act_participation_2017  act_english_2017  act_math_2017  \
# 4            1055                    31.0              22.5           22.7
#
#    act_reading_2017  act_science_2017  act_composite_2017  \
# 4              23.1              22.2                22.8
#
#    sat_participation_2018  sat_rw_2018  sat_math_2018  sat_total_2018  \
# 4                    60.0          540            536            1076
#
#    act_participation_2018  act_composite_2018
# 4                    27.0                22.7

# %% [markdown]
# According to the Daily Beast
#
# It is estimated that every year, the College Board flags 2,500 cases of scores that look suspect. If this is true, it is a small sample based on 2,000,0000 students taking one or both of the tests in 2018.
#
# https://www.thedailybeast.com/sat-cheaters-college-admissions-exam-has-history-of-fraud

# %% [markdown]
# ## Conclusions and Recommendations

# %% [markdown]
# Based on your exploration of the data, what are you key takeaways and recommendations? Choose one state with a lower participation rate and provide a suggestion for how the College Board might increase participation amongst graduating seniors in this state. Are there additional data you desire that would better inform your investigations?

# %% [markdown]
# Key takeaway: I think it is important to note correlation between states having a high participation for one test being very low for the other.  It seems we can deduce that few students want to take both tests so in states where one is mandatory, the other is very low.
#
# North Dakota SAT participation is very low.  If we made that test free, but not manadatory, I think the number of students taking it would definitely increase.
#
# I would have liked to dive deeper into the necessity of the tests.  They seem like an ancient and inaccurate tool.  Especially with the recent college admissions scandals in the news, I think it would be important to figure out the percent of fraudulent high scoring tests last year and focus on fixing that problem first.
